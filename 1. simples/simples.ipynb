# %% [markdown]
# ## String en python 'str'
#
# Metodos mas utilizados son:
# * len(string)
# * str.upper()
# * str.lower()
# * str.strip()
# * str.split()

# %%
mi_string = "Hola, Mundo!"
print(mi_string)
type(mi_string)
# Out:
# Hola, Mundo!
# str

# %% [markdown]
# ## 'int', ENTEROS

# %%
mi_int = 42
print(mi_int)
type(mi_int)
# Out:
# 42
# int

# %% [markdown]
# ## 'float', DECIMALES

# %%
mi_float = 3.14
print(mi_float)
type(mi_float)

# %% [markdown]
# ## 'bool', BOOLEANOS

# %%
mi_bool = True
print(mi_bool)
type(mi_bool)

# %% [markdown]
# ## NONE - representa el valor nulo

# %%
mi_none = None
print(mi_none)
type(mi_none)
# Out:
# None
# NoneType
